# %%
import matplotlib.pyplot as plt
from matplotlib.offsetbox import AnchoredText
import mplhep as hep
from coffea.util import load
from coffea import hist
from coffea.hist import plot
import os

# %%
output = load("histograms/hists_dilepton_mc2017.coffea")
output
# Out:
# {'sumw': defaultdict_accumulator(float, {}),
#  'hist_muons_pt_basic_weights_ones': <Hist (dataset,values) instance at 0x7f0c4a2d01d0>,
#  'hist_muons_eta_basic_weights_ones': <Hist (dataset,values) instance at 0x7f0bfd7e0fd0>,
#  'hist_goodmuons_pt_basic_weights_ones': <Hist (dataset,values) instance at 0x7f0bfd7e72d0>,
#  'hist_goodmuons_eta_basic_weights_ones': <Hist (dataset,values) instance at 0x7f0bfd7e7550>,
#  'hist_electrons_pt_basic_weights_ones': <Hist (dataset,values) instance at 0x7f0bfd7e77d0>,
#  'hist_electrons_eta_basic_weights_ones': <Hist (dataset,values) instance at 0x7f0bfd7e7a50>,
#  'hist_goodelectrons_pt_basic_weights_ones': <Hist (dataset,values) instance at 0x7f0bfd7e7d10>,
#  'hist_goodelectrons_eta_basic_weights_ones': <Hist (dataset,values) instance at 0x7f0bfd7e7f90>,
#  'hist_jets_pt_basic_weights_ones': <Hist (dataset,values) instance at 0x7f0bfd7ee250>,
#  'hist_jets_eta_basic_weights_ones': <Hist (dataset,values) instance at 0x7f0bfd7ee4d0>,
# ...

# %%
plt.style.use(hep.style.ROOT)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,9))
hist.plot1d(output['hist_leadAK8JetMass_basic_weights_ones'], density=True)
plt.xlim(50,200)
plt.show()
plt.close(fig)

# %%
plt.style.use(hep.style.ROOT)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,9))
hist.plot1d(output['hist_leadAK8JetMass_boost_weights_ones'], density=True)
plt.xlim(50,200)
plt.show()
plt.close(fig)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,9))
hist.plot1d(output['hist_leadAK8JetMass_2l2b_weights_ones'], density=True)
plt.xlim(50,200)
plt.show()
plt.close(fig)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,9))
hist.plot1d(output['hist_deltaPhiHiggsTop_boost_weights_ones'], density=True)
plt.show()
plt.close(fig)
# Out:
# findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,9))
hist.plot1d(output['hist_leading_fatjet_Hbb_basic_weights_nominal'], density=True)
plt.show()
plt.close(fig)

# %%
output['hist_leading_fatjet_Hbb_basic_weights_nominal'].values()
# Out:
# {('TTTo2L2Nu',): array([24.24019209, 22.5997856 , 16.85219595, 11.09638372,  8.62960705,
#          4.52242389,  4.11129445,  2.46677667,  4.09900171,  2.87790611,
#          4.92944205,  1.64040649,  2.87790611,  1.23338833,  1.64451778,
#          1.64451778,  1.23338833,  0.82225889,  1.23338833,  0.41112944,
#          1.64451778,  0.        ,  0.41112944,  0.82225889,  0.41112944,
#          0.82225889,  0.41112944,  1.64451778,  0.41112944,  0.        ,
#          0.41112944,  0.41112944,  0.41112944,  1.23338833,  0.82225889,
#          0.41112944,  0.8181476 ,  0.        ,  1.64040649,  1.23338833,
#          0.        ,  1.23338833,  0.41112944,  0.82225889,  1.64040649,
#          0.41112944,  1.64451778,  0.        ,  0.        ,  0.        ]),
#  ('ttHTobb',): array([0.01722022, 0.02191665, 0.0187857 , 0.00469642, 0.0062619 ,
#         0.00313095, 0.00313095, 0.00156547, 0.00156547, 0.00156547,
#         0.0062619 , 0.00313095, 0.        , 0.        , 0.00313095,
# ...

# %%
for item in output:
    if 'hist2d' in item:
        print(item)
# Out:
# hist2d_m_top_vs_pnu_x_basic_weights_ones
# hist2d_m_top_vs_pnu_x_boost_weights_ones
# hist2d_m_top_vs_pnu_x_2l2b_weights_ones
# hist2d_m_top_vs_pnu_x_2l2bHbb_weights_ones
# hist2d_m_top_vs_pnu_x_2l2bmw_weights_ones
# hist2d_m_top_vs_pnu_x_2l2bHbbmw_weights_ones
# hist2d_m_top_vs_pnu_x_2l2bmwmt_weights_ones
# hist2d_m_top_vs_pnu_x_2l2bHbbmwmt_weights_ones
# hist2d_m_top_vs_pnu_x_2l2bhighmt_weights_ones
# hist2d_m_top_vs_pnu_x_basic_weights_nominal
# hist2d_m_top_vs_pnu_x_boost_weights_nominal
# hist2d_m_top_vs_pnu_x_2l2b_weights_nominal
# hist2d_m_top_vs_pnu_x_2l2bHbb_weights_nominal
# hist2d_m_top_vs_pnu_x_2l2bmw_weights_nominal
# hist2d_m_top_vs_pnu_x_2l2bHbbmw_weights_nominal
# hist2d_m_top_vs_pnu_x_2l2bmwmt_weights_nominal
# hist2d_m_top_vs_pnu_x_2l2bHbbmwmt_weights_nominal
# hist2d_m_top_vs_pnu_x_2l2bhighmt_weights_nominal

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,9))
hist.plot2d(output['hist2d_m_top_vs_pnu_x_2l2bhighmt_weights_ones'].sum('dataset'), xaxis='x')
plt.xlim(0,100)
plt.ylim(0,500)
plt.show()
plt.close(fig)
