# %%
import pandas as pd
import numpy as np
import awkward as ak
import matplotlib.pyplot as plt

# %%
inputfile = "/work/mmarcheg/ttHbb/inputs/hists_dilepton_baseline_samples_2017_withdR/hists_dilepton_baseline_samples_2017_withdR.h5"
df = pd.read_hdf(inputfile)
df
# Out:
#         njets  ngoodjets  btags  nfatjets      met_pt   met_phi  \
# entry
# 0         0.0        4.0    0.0       2.0   28.602549  1.688477
# 1         1.0        4.0    1.0       1.0  858.796936  1.734619
# 2         2.0        6.0    1.0       1.0  159.624634 -3.119141
# 3         0.0        4.0    2.0       1.0   66.019257 -0.304077
# 4         0.0        3.0    1.0       1.0  132.988358  1.145020
# ...       ...        ...    ...       ...         ...       ...
# 254420    0.0        3.0    1.0       1.0   65.279831 -1.355713
# 254421    1.0        7.0    2.0       1.0   92.660004  2.792480
# 254422    2.0        4.0    1.0       1.0   34.013538  0.333801
# 254423    0.0        3.0    2.0       1.0   82.803436  2.086426
# 254424    0.0        2.0    1.0       1.0   86.181534  1.169922
#
#         leading_jet_pt  leading_jet_eta  leading_jet_phi  leading_jet_mass  \
# entry
# 0               0.0000         0.000000         0.000000          0.000000
# ...

# %%
#variables = [var for ]
corr = df.corr()
#corr.style.background_gradient(cmap='RdYlGn').set_precision(2)
f = plt.figure(figsize=(19, 15))
plt.matshow(corr, fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=10)
plt.title('Correlation Matrix', fontsize=16);

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# ...
